# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import os
import numpy as np
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Activation
from tensorflow.keras.models import Sequential
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing import image
from keras.optimizers import *
from tensorflow.keras import *
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D,BatchNormalization,Input, Lambda
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image

# %%
IMAGE_SIZE = [224, 224]

# %%
train_path = "C:\\Users\\Nethmi Mohotti\\Desktop\\CobraShot\\Data Science\\dataset\\train"
test_path = "C:\\Users\\Nethmi Mohotti\\Desktop\\CobraShot\\Data Science\\dataset\\testing"

# %%
vgg = VGG16(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)

# %%
for layer in vgg.layers:
  layer.trainable = False

# %%
from glob import glob
folders = glob("C:\\Users\\Nethmi Mohotti\\Desktop\\CobraShot\\Data Science\\dataset\\train\\*")
print(len(folders))
# Out:
# 7

# %%
x = Flatten()(vgg.output)

# %%
prediction = Dense(len(folders), activation='softmax')(x)

# %%
model = Model(inputs=vgg.input, outputs=prediction)

# %%
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 7)                 175623
#
# =================================================================
# Total params: 14,890,311
# Trainable params: 175,623
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
train_dataset = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_dataset = ImageDataGenerator(rescale = 1./255)

# %%
training_set = train_dataset.flow_from_directory(train_path,
                                                 target_size = (224, 224),
                                                 batch_size = 32,
                                                 class_mode = 'categorical')

testing_set = test_dataset.flow_from_directory(test_path, 
                                                 target_size = (224, 224),
                                                 batch_size = 32,
                                                 class_mode = 'categorical')
# Out:
# Found 2473 images belonging to 7 classes.
# Found 83 images belonging to 7 classes.

# %%
training_set.class_indices
# Out:
# {'Black rat snake': 0,
#  'Common garter snake': 1,
#  'Common watersnake': 2,
#  "Russell's Viper": 3,
#  'Saw-scaled Viper': 4,
#  'Spectacled Cobra': 5,
#  'Western diamondback rattlesnake': 6}

# %%
cobrashot_m = model.fit(
  training_set,
  validation_data=testing_set,
  epochs=35,
  steps_per_epoch=len(training_set),
  validation_steps=len(testing_set)
)
# Out:
# Epoch 1/35
# 78/78 [==============================] - 335s 4s/step - loss: 1.5029 - accuracy: 0.4865 - val_loss: 1.2032 - val_accuracy: 0.5663
# Epoch 2/35
# 78/78 [==============================] - 345s 4s/step - loss: 0.9831 - accuracy: 0.6417 - val_loss: 1.1068 - val_accuracy: 0.5904
# Epoch 3/35
# 78/78 [==============================] - 358s 5s/step - loss: 0.8904 - accuracy: 0.6789 - val_loss: 0.8755 - val_accuracy: 0.6265
# Epoch 4/35
# 78/78 [==============================] - 370s 5s/step - loss: 0.6794 - accuracy: 0.7550 - val_loss: 0.9670 - val_accuracy: 0.6506
# Epoch 5/35
# 78/78 [==============================] - 409s 5s/step - loss: 0.6473 - accuracy: 0.7675 - val_loss: 0.7918 - val_accuracy: 0.6627
# Epoch 6/35
# 78/78 [==============================] - 592s 8s/step - loss: 0.5988 - accuracy: 0.7829 - val_loss: 1.0287 - val_accuracy: 0.6747
# Epoch 7/35
# 78/78 [==============================] - 535s 7s/step - loss: 0.5360 - accuracy: 0.8180 - val_loss: 1.0064 - val_accuracy: 0.6265
# Epoch 8/35
# Epoch 26/35
# 78/78 [==============================] - 319s 4s/step - loss: 0.1838 - accuracy: 0.9499 - val_loss: 1.1451 - val_accuracy: 0.6867
# Epoch 27/35
# 78/78 [==============================] - 320s 4s/step - loss: 0.1679 - accuracy: 0.9511 - val_loss: 1.3779 - val_accuracy: 0.6506
# Epoch 28/35
# 78/78 [==============================] - 319s 4s/step - loss: 0.1838 - accuracy: 0.9414 - val_loss: 1.3180 - val_accuracy: 0.6386
# Epoch 29/35
# 78/78 [==============================] - 319s 4s/step - loss: 0.1526 - accuracy: 0.9539 - val_loss: 0.9863 - val_accuracy: 0.7229
# Epoch 30/35
# 78/78 [==============================] - 318s 4s/step - loss: 0.1295 - accuracy: 0.9616 - val_loss: 1.2325 - val_accuracy: 0.6506
# Epoch 31/35
# 78/78 [==============================] - 326s 4s/step - loss: 0.1468 - accuracy: 0.9588 - val_loss: 1.1936 - val_accuracy: 0.6747
# Epoch 32/35
# 78/78 [==============================] - 321s 4s/step - loss: 0.1538 - accuracy: 0.9624 - val_loss: 1.1408 - val_accuracy: 0.6988
# Epoch 33/35
# 78/78 [==============================] - 319s 4s/step - loss: 0.1095 - accuracy: 0.9733 - val_loss: 1.0237 - val_accuracy: 0.6988
# Epoch 34/35
# 78/78 [==============================] - 320s 4s/step - loss: 0.1471 - accuracy: 0.9547 - val_loss: 1.2383 - val_accuracy: 0.6867
# Epoch 35/35
# 78/78 [==============================] - 323s 4s/step - loss: 0.1662 - accuracy: 0.9482 - val_loss: 1.0180 - val_accuracy: 0.7229

# %%
cobrashot_m.history??

# %%
cobrashot_m.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize training for accuracy
plt.plot(cobrashot_model.history['accuracy'])
plt.plot(cobrashot_model.history['val_accuracy'])
plt.title('Accuracy graph')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['train','test'], loc='upper left')
plt.show()

# %%
# summarize training for loss
plt.plot(cobrashot_m.history['loss'])
plt.plot(cobrashot_m.history['val_loss'])
plt.title('Loss graph')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train','test'], loc='upper left')
plt.show()

# %%
# testing the model
print('************Image identification******************')
img = image.load_img('C:\\Users\\Nethmi Mohotti\\Desktop\\CobraShot\\Data Science\\dataset\\validation\\picture.jpeg', target_size=(224, 224))
plt.imshow(img)
plt.show()

x =image.img_to_array(img)
x = np.expand_dims(x,axis=0)
images = np.vstack([x]) 
pred = model.predict(images)
prediction= pred[0]
for k in range(7):
    if prediction[k] == 1:
      print('Snake Identified')
    else:
      print('Unidentified')
# Out:
# ************Image identification******************
# Unidentified
# Unidentified
# Unidentified
# Unidentified
# Snake Identified
# Unidentified
# Unidentified

# %%
#create the model
from tensorflow.keras.models import load_model
model.save('cobrashot_m.h5')

# %%
#load the model and save
from keras.models import load_model
cobrashot_model = load_model('cobrashot_m.h5')
